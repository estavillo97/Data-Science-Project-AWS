# %% [markdown]
# # Challenge Description

# %% [markdown]
# Identify the longest journey a user
# took before reaching TripAdvisor. \
# Provide a comprehensive analysis of this journey, explaining what it
# may reveal about the user's behavior and intentions.

# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # Functions

# %%
def get_longest_journey(user_journeys: pd.DataFrame) -> pd.Series:
    column = user_journeys.count().idxmax()
    longest_journey = user_journeys[column]
    return longest_journey

# %% [markdown]
# # Data

# %%
user_journeys = pd.read_parquet('data/user_journeys.parquet')
user_journeys
# Out:
#       0caeb7a6-1496-4ede-9483-4b685881478f_0  \
# index
# 0                                  wikipedia
# 1                                      apple
# 2                             myreadingmanga
# 3                                arigatomina
# 4                                  mediafire
# ...                                      ...
# 160                                     None
# 161                                     None
# 162                                     None
# 163                                     None
# 164                                     None
#
#       0caeb7a6-1496-4ede-9483-4b685881478f_1  \
# index
# 0                                     google
# 1                                     google
# 2                                     google
# 3                                arigatomina
# 4                                     google
# ...                                      ...
# 160                                     None
# 161                                     None
# 162                                     None
# 163                                     None
# 164                                     None
#
#       0caeb7a6-1496-4ede-9483-4b685881478f_2  \
# index
# 0                                     google
# 1                               johnnys-shop
# 2                                     google
# 3                                         id
# 4                                     google
# ...                                      ...
# 160                                     None
# 161                                     None
# 162                                     None
# 163                                     None
# 164                                     None
#
#       0caeb7a6-1496-4ede-9483-4b685881478f_3  \
# index
# 0                                     ralphs
# 1                                     amazon
# 2                                     google
# 3                             pressedjuicery
# 4                                     google
# ...                                      ...
# 160                                   redfin
# 161                                  shakeys
# 162                                   amazon
# 163                          archiveofourown
# 164                              tripadvisor
#
#       0caeb7a6-1496-4ede-9483-4b685881478f_4  \
# index
# 0                                  overdrive
# 1                                tripadvisor
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 160                                     None
# 161                                     None
# 162                                     None
# 163                                     None
# 164                                     None
#
#       0caeb7a6-1496-4ede-9483-4b685881478f_5  \
# index
# 0                                     amazon
# 1                                tripadvisor
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 160                                     None
# 161                                     None
# 162                                     None
# 163                                     None
# 164                                     None
#
#       0caeb7a6-1496-4ede-9483-4b685881478f_6  \
# index
# 0                                     amazon
# 1                                tripadvisor
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 160                                     None
# 161                                     None
# 162                                     None
# 163                                     None
# 164                                     None
#
#       0caeb7a6-1496-4ede-9483-4b685881478f_7  \
# index
# 0                                     google
# 1                                tripadvisor
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 160                                     None
# 161                                     None
# 162                                     None
# 163                                     None
# 164                                     None
#
#       0caeb7a6-1496-4ede-9483-4b685881478f_8  \
# index
# 0                                    doccafe
# 1                                tripadvisor
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 160                                     None
# 161                                     None
# 162                                     None
# 163                                     None
# 164                                     None
#
#       0caeb7a6-1496-4ede-9483-4b685881478f_9
# index
# 0                                friendsofcc
# 1                                tripadvisor
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 160                                     None
# 161                                     None
# 162                                     None
# 163                                     None
# 164                                     None
#
# [165 rows x 10 columns]

# %%
longest_journey = get_longest_journey(user_journeys)
longest_journey
# Out:
# index
# 0               ralphs
# 1               amazon
# 2               google
# 3       pressedjuicery
# 4               google
#             ...
# 160             redfin
# 161            shakeys
# 162             amazon
# 163    archiveofourown
# 164        tripadvisor
# Name: 0caeb7a6-1496-4ede-9483-4b685881478f_3, Length: 165, dtype: object

# %% [markdown]
# # Visualizations

# %% [markdown]
# # Conclusions

# %%
# Out:
#   Cell In [1], line 5
#     I've been working on the challenge and I would love to get some feedback before submiting the whole challenge.
#      ^
# SyntaxError: unterminated string literal (detected at line 5)
