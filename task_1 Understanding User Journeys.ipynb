# %% [markdown]
# # Description

# %% [markdown]
# Analyze the clickstream data to identify the most common user journeys leading to TripAdvisor.
#
# What patterns or sequences of sites or pages do users typically navigate through before reaching TripAdvisor?
# Are there specific categories, themes, or domains that are common in these preTripAdvisor sessions?
#
# Interpret your findings (visualization and statistical analysis is optional, but it will increase your valuation as a candidate).

# %% [markdown]
# # Imports Libraries

# %%
# standard libraries
import os
import pandas as pd
from collections import Counter

# external libraries
import plotly.express as px
import tldextract

# %% [markdown]
# # Data cleaning

# %%
def get_clean_data(file: str) -> pd.DataFrame:
    '''Returns the data cleaned after the process of:
           ordering it, 
           add domain,
           and subdomain. 
       It also saves the new file for future iteration'''
    if os.path.exists(f'data/clean_{file}'):
        return pd.read_parquet(f'data/clean_{file}')
    
    data = order_data(pd.read_parquet(f'data/{file}'))
    data['domain'] = data['targeturl'].apply(get_domain)
    data['sub_domain'] = data['targeturl'].apply(get_sub_domain)
    data.to_parquet(f'data/clean_{file}')
    return data

# %%
def order_data(data: pd.DataFrame) -> pd.DataFrame:
    '''Returns the data ordered by the id and the timestamp'''
    sorted_ids = dict(zip(data.userid.unique(), range(len(data.userid.unique()))))
    data['sortedids'] = data.userid.map(sorted_ids)
    data = data.sort_values(['sortedids', 'eventtimestamp'])
    data.drop(columns=['sortedids'])
    return data

# %%
def get_domain(url: str) -> str:
    '''Returns the domain of an url,
    using the library tldextract'''
    try:
        return tldextract.extract(url)[1]
    except:
        return np.nan

# %%
def get_sub_domain(url: str) -> str:
    '''Returns the sub domain of an url,
    using the library tldextract'''
    try:
        return tldextract.extract(url)[0]
    except:
        return np.nan

# %% [markdown]
# # Data Transformation

# %%
def get_user_journeys(data: pd.DataFrame, 
                      max_timestamp: int=14400,
                      n_file: int=0) -> pd.DataFrame:
    '''journey refers to a series of clicks, 
    page views, and user actions occurring within a specific 
    time frame that ultimately leads to TripAdvisor.
    This function returns a DataFrame with these user journeys
    to obtain insights into user preferences, 
    behaviors, and decision-making processes.
    The function receives the data as a dataframe and a max 
    timestamp to separate journeys'''

    # start variables id and current journey
    n = 0
    current_id = f'{data.userid[0]}_{n}'

    # base
    users = data.userid.unique()
    user_journey = [tldextract.extract(data.referrerurl.iloc[0])[1]]
    user_journeys = pd.DataFrame(index=range(len(data) // len(users)))

    # check every row
    for idx in range(len(user_journeys.index) - 1):
        row = data.iloc[idx]
        if data.domain.iloc[idx] == 'tripadvisor':
            user_journey.append(data.domain.iloc[idx])
            user_journeys[current_id] = pd.Series(user_journey)

            # start another user journey for new user
            user_journey = []
            n += 1
            current_id = f'{data.userid[idx]}_{n}'
            

        elif data.userid[idx] != current_id[:36]:
            # start another user journey for new user
            user_journey = []
            
            # new id
            n = 0
            current_id = f'{data.userid[idx]}_{n}'

        
        elif (data.eventtimestamp.iloc[idx + 1] \
              - data.eventtimestamp.iloc[idx]) > max_timestamp:
            # start another user journey for new user
            user_journey = []
            current_id = f'{data.userid[idx]}_{n}'
            
        
        # append the url in the same journey
        user_journey.append(data.domain[idx])

    
    # drop empty rows and save the file
    user_journeys = user_journeys.dropna(how='all')
    user_journeys.to_parquet(f'data/user_journeys_{n_file}.parquet')
    
    return user_journeys

# %% [markdown]
# # Data Import

# %%
# prepare and import all data.
user_journeys = pd.DataFrame()
for n in range(48):
    file = f'data_{n}.parquet'
    data = get_clean_data(file)
    new_user_journeys = get_user_journeys(data, n_file=n)
    user_journeys = pd.concat([user_journeys, new_user_journeys], axis=1)

# %%
# save and display user journeys
user_journeys.to_parquet('data/complete_user_journeys.parquet')
user_journeys
# Out:
#     0caeb7a6-1496-4ede-9483-4b685881478f_0  \
# 0                                wikipedia
# 1                                    apple
# 2                           myreadingmanga
# 3                              arigatomina
# 4                                mediafire
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     0caeb7a6-1496-4ede-9483-4b685881478f_1  \
# 0                                   google
# 1                                   google
# 2                                   google
# 3                              arigatomina
# 4                                   google
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     0caeb7a6-1496-4ede-9483-4b685881478f_2  \
# 0                                   google
# 1                             johnnys-shop
# 2                                   google
# 3                                       id
# 4                                   google
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     0caeb7a6-1496-4ede-9483-4b685881478f_3  \
# 0                                   ralphs
# 1                                   amazon
# 2                                   google
# 3                           pressedjuicery
# 4                                   google
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     0caeb7a6-1496-4ede-9483-4b685881478f_4  \
# 0                                overdrive
# 1                              tripadvisor
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     0caeb7a6-1496-4ede-9483-4b685881478f_5  \
# 0                                   amazon
# 1                              tripadvisor
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     0caeb7a6-1496-4ede-9483-4b685881478f_6  \
# 0                                   amazon
# 1                              tripadvisor
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     0caeb7a6-1496-4ede-9483-4b685881478f_7  \
# 0                                   google
# 1                              tripadvisor
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     0caeb7a6-1496-4ede-9483-4b685881478f_8  \
# 0                                  doccafe
# 1                              tripadvisor
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     0caeb7a6-1496-4ede-9483-4b685881478f_9  ...  \
# 0                              friendsofcc  ...
# 1                              tripadvisor  ...
# 2                                      NaN  ...
# 3                                      NaN  ...
# 4                                      NaN  ...
# ..                                     ...  ...
# 429                                    NaN  ...
# 430                                    NaN  ...
# 431                                    NaN  ...
# 432                                    NaN  ...
# 433                                    NaN  ...
#
#     4f33a1af-02f1-4205-b38f-54ebbaf88bcf_7  \
# 0                                   amazon
# 1                                   amazon
# 2                                   amazon
# 3                        americangreetings
# 4                                 medicare
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     4f33a1af-02f1-4205-b38f-54ebbaf88bcf_8  \
# 0                                   amazon
# 1                                    9xbud
# 2                                 xgaytube
# 3                                   amazon
# 4                                   amazon
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     4f33a1af-02f1-4205-b38f-54ebbaf88bcf_9  \
# 0                                   amazon
# 1                              tripadvisor
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 429                                    NaN
# 430                                    NaN
# 431                                    NaN
# 432                                    NaN
# 433                                    NaN
#
#     4f33a1af-02f1-4205-b38f-54ebbaf88bcf_10  \
# 0                                    amazon
# 1                               tripadvisor
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 429                                     NaN
# 430                                     NaN
# 431                                     NaN
# 432                                     NaN
# 433                                     NaN
#
#     4f33a1af-02f1-4205-b38f-54ebbaf88bcf_11  \
# 0                                    amazon
# 1                               tripadvisor
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 429                                     NaN
# 430                                     NaN
# 431                                     NaN
# 432                                     NaN
# 433                                     NaN
#
#     4f33a1af-02f1-4205-b38f-54ebbaf88bcf_12  \
# 0                                    amazon
# 1                               tripadvisor
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 429                                     NaN
# 430                                     NaN
# 431                                     NaN
# 432                                     NaN
# 433                                     NaN
#
#     4f33a1af-02f1-4205-b38f-54ebbaf88bcf_13  \
# 0                                    amazon
# 1                                  medicare
# 2                                    viator
# 3                                  outbrain
# 4                     domesticatedcompanion
# ..                                      ...
# 429                                     NaN
# 430                                     NaN
# 431                                     NaN
# 432                                     NaN
# 433                                     NaN
#
#     4f33a1af-02f1-4205-b38f-54ebbaf88bcf_14  \
# 0                               tripadvisor
# 1                               tripadvisor
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 429                                     NaN
# 430                                     NaN
# 431                                     NaN
# 432                                     NaN
# 433                                     NaN
#
#     4f33a1af-02f1-4205-b38f-54ebbaf88bcf_15  \
# 0                                    amazon
# 1                               tripadvisor
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 429                                     NaN
# 430                                     NaN
# 431                                     NaN
# 432                                     NaN
# 433                                     NaN
#
#     4f33a1af-02f1-4205-b38f-54ebbaf88bcf_16
# 0                                    amazon
# 1                               tripadvisor
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 429                                     NaN
# 430                                     NaN
# 431                                     NaN
# 432                                     NaN
# 433                                     NaN
#
# [434 rows x 367 columns]

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# ## Descriptive Analysis

# %%
def get_pages_visited(user_journeys: pd.DataFrame) -> list:
    '''Returns a list pages visited sorted alphabetically'''
    # we have to make the dataframe to a single column
    pages_visited = list(pd.melt(user_journeys).value.dropna())

    # clean and order
    pages_visited = [word for word in pages_visited if word not in ['tripadvisor']]
    pages_visited = sorted(pages_visited)
    return pages_visited

# %%
def get_descriptive_data(pages_visited: list):
    '''Returns descriptive statistics for analysis'''
    unique_pages = len(pd.Series(pages_visited).unique())
    
    top_25_pages = dict(Counter(pages_visited).most_common(5)).keys()
    top_25_percentages = dict(Counter(pages_visited).most_common(5)).values()
    
    top_5_pages = dict(Counter(pages_visited).most_common(5)).keys()
    top_5_percentages = dict(Counter(pages_visited).most_common(5)).values()
    
    top_page = top_5_pages[0]
    top_percentage = top_5_pages[1]
    
    te = Counter(pages_visited).most_common(5)
    sum(dict(te).values()) / len(pages_visited)
    users = len(user_journeys.columns)
    return users, unt, unique_pages, most_comon, frequency, per_80

# %%
def get_most_visite_before_tripadvisor(user_journeys: pd.DataFrame) -> dict:
    return most_visited_before_tripadvisor

# %%
# get descriptive statistics
users,  = get_descriptive_data(pages_visited)

# %%
pages_visited = get_pages_visited(user_journeys)

# %%
f'There was a total 48 files, where {users} where analyzed in {user_journeys} user journeys. \
The most common page visited was {top_page}, with a frequency of {top_percentage}. \
, this is where we should focus, this is where the engagement will come from \
to enhance the pressence in {top_page}, being google the center of the internet.\
A third of the trafic comes only from 5 pages {top_5} \ This is where'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [105], line 1
# ----> 1 f'There was a total 48 files, where {users} where analyzed in {user_journeys} user journeys. \
#       2 The most common page visited was {top_page}, with a frequency of {top_percentage}. \
#       3 , this is where we should focus, this is where the engagement will come from \
#       4 to enhance the pressence in {top_page}, being google the center of the internet.\
#       5 A third of the trafic comes only from 5 pages {top_5} \ This is where'
#
# NameError: name 'users' is not defined

# %% [markdown]
# # Visualization

# %%
def plot_most_common_pages(pages_visited: list) -> None:
    '''plot in an histogram the amount of times each page was visited in all data'''
    
    # create the plot
    plot = px.histogram(pages_visited,
                       x=pages_visited,
                       title='Most visited pages')
    
    # order values
    plot.update_xaxes(categoryorder="total descending")
    # Show the histogram
    plot.show()

# %%
def plot_most_common_by_category(pages_visited: list) -> None:
    # Create a sample list of values
    top_25 = dict(Counter(pages_visited).most_common(25))
    values = top_25.keys()

    # Create a DataFrame to count the occurrences
    value_counts = pd.DataFrame({'Value': values})
    value_counts['Count'] = list(top_25.values())

    # Group by 'Value' and sum the counts
    #value_counts = value_counts.groupby('Value').sum().reset_index()

    size = list(top_25.values()) 

    # Create a bubble chart using Plotly Express
    color = ['search', 'consumer / finance', 'travel', 'consumer / finance', 
             'social media', 'social media', 'travel', 'consumer / finance', 
             'travel', 'travel', 'search', 'travel', 'travel', 'consumer / finance', 
             'other', 'travel', 'travel', 'travel', 'travel', 'social media',
             'travel', 'search', 'social media', 'other', 'other']

    fig = px.scatter(value_counts,
                     x='Value', 
                     y='Count', 
                     size=size, 
                     title='Value Frequencies by category', 
                     color=color)
    fig.show()

# %%
plot_most_common_pages(top_25)
# Out:
# <div>                            <div id="5b1ca468-84b1-4b6e-8f02-471fc9740558" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b1ca468-84b1-4b6e-8f02-471fc9740558")) {                    Plotly.newPlot(                        "5b1ca468-84b1-4b6e-8f02-471fc9740558",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"x=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["","","10best","10best","11points","12go","12go","12go","12go","12go","1iota","1iota","1iota","1steam1","1steam1","209times","23andme","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2mdn","2minutemedicine","3lift","3lift","3lift","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","4chan","53bythesea","53westapts","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","9xbud","aa","aafp","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aamc","aan","aan","aana","abercrombie","abiomed","abiomed","abiomed","abiomed","accuweather","accuweather","accuweather","accuweather","accuweather","accuweather","ad4m","addictivetips","additudemag","addthis","addthis","addthis","addthis","admintool","admissioncounseling","admissioncounseling","adobe","adobe","adobe","adobelogin","adthrive","adthrive","adventurenation","aeries","affinity","affinity","affordabletours","affordabletours","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","agoda","ahajournals","ahajournals","ahcdn","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnb","airbnbpayments","airdoctorpro","aka","aldoshoes","aliexpress","aliexpress","aliexpress","allareacodes","allears","alleghenycounty","allegiantair","allegiantair","allergandirect","allevents","allevents","allevents","allrecipes","allrecipes","alltrails","alltrails","ally","ally","ally","ally","ally","ally","altatennis","alwaysdata","alwaysdata","alz","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon","amazon"," ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Google is the number one by far, we should focus on SEO to improve the possibilities for users for their journey to finish in tripadvisor

# %% [markdown]
# ### Add Categories

# %%
plot_most_common_by_category(pages_visited)
# Out:
# <div>                            <div id="e693aa63-88b7-4c53-a880-c7dd3a9bd310" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e693aa63-88b7-4c53-a880-c7dd3a9bd310")) {                    Plotly.newPlot(                        "e693aa63-88b7-4c53-a880-c7dd3a9bd310",                        [{"hovertemplate":"color=search\u003cbr\u003eValue=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003esize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"search","marker":{"color":"#636efa","size":[1959,87,49],"sizemode":"area","sizeref":4.8975,"symbol":"circle"},"mode":"markers","name":"search","orientation":"v","showlegend":true,"x":["google","duckduckgo","yahoo"],"xaxis":"x","y":[1959,87,49],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=consumer \u002f finance\u003cbr\u003eValue=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003esize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"consumer \u002f finance","marker":{"color":"#EF553B","size":[298,151,100,67],"sizemode":"area","sizeref":4.8975,"symbol":"circle"},"mode":"markers","name":"consumer \u002f finance","orientation":"v","showlegend":true,"x":["amazon","chase","costco","americanexpress"],"xaxis":"x","y":[298,151,100,67],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=travel\u003cbr\u003eValue=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003esize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"travel","marker":{"color":"#00cc96","size":[262,102,95,90,75,70,61,58,57,52,49],"sizemode":"area","sizeref":4.8975,"symbol":"circle"},"mode":"markers","name":"travel","orientation":"v","showlegend":true,"x":["ana","airbnb","expertflyer","expedia","flyertalk","booking","indianvisaonline","melia","vacationexpress","miami","rci"],"xaxis":"x","y":[262,102,95,90,75,70,61,58,57,52,49],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=social media\u003cbr\u003eValue=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003esize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"social media","marker":{"color":"#ab63fa","size":[142,104,51,49],"sizemode":"area","sizeref":4.8975,"symbol":"circle"},"mode":"markers","name":"social media","orientation":"v","showlegend":true,"x":["facebook","youtube","linkedin","yelp"],"xaxis":"x","y":[142,104,51,49],"yaxis":"y","type":"scatter"},{"hovertemplate":"color=other\u003cbr\u003eValue=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003esize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"other","marker":{"color":"#FFA15A","size":[65,47,40],"sizemode":"area","sizeref":4.8975,"symbol":"circle"},"mode":"markers","name":"other","orientation":"v","showlegend":true,"x":["mautam","wikipedia","padi"],"xaxis":"x","y":[65,47,40],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22 ...

# %% [markdown]
# ### Conclusion

# %%
the other 2 categories most visited during the journey are social media

# %%
# add most common journey to trip advisor here
